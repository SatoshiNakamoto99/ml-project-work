# %%
# You can follow this tutorial for more information - https://www.tutorialspoint.com/google_colab/index.htm
# You can also see this video - https://www.youtube.com/watch?v=inN8seMm7UI

# Mount your Drive - After doing this step, your Google Drive folders are accessible from Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Use it as a standard Linux console, by prepending ! to the commands.

# Install all the requirements
# !pip install opencv-python
# !apt-get install aria2 

# Example of apt-get
# !apt-get install protobuf-compiler python-pil python-lxml python-tk

# Example of setup Tensorflow version
# %tensorflow_version 2.x

# %%
# Move into the folder where you have the script test.py and all you need to run your test
# I downloaded the archive ONFIRE2023_Example_Code.zip in my Google Drive root /content/gdrive/My Drive/ but you can use different folders.
# %cd '/content/gdrive/My Drive/ONFIRE2023_Example_Code/'

# %%
# Run the test
# --videos is the path of the folder with the test videos. Use the provided foo_videos/ to check if your code works.
# --results is the path of the folder in which the predictions of your model should be written. A sample foo_results/ is provided.
# !python test.py --videos ./ONFIRE2023_Example_Code/foo_videos/ --results ./ONFIRE2023_Example_Code/foo_results/
# Out:
# Loading model mobilenet-v3l from path experiments/mobilenet-v3l/foggia-mod/fold_0_best_model.pth trained with foggia-mod base model  mobilenet-v3l
# Processing video Video1.mp4 @ 10.0 FPS...video Video1.mp4 is positive on frame 297 (at time 30 seconds) with 0.15156888961791992 GB of memory used
# Processing video Video0.mp4 @ 29.97002997002997 FPS...video Video0.mp4 is positive on frame 0 (at time 0 seconds) with 0.15156888961791992 GB of memory used
# Processing video Video2.mp4 @ 9.0 FPS...video Video2.mp4 is positive on frame 0 (at time 0 seconds) with 0.15156888961791992 GB of memory used
# Processing video Video103.mp4 @ 8.333333333333334 FPS...video Video103.mp4 is positive on frame 63 (at time 8 seconds) with 0.15156888961791992 GB of memory used
